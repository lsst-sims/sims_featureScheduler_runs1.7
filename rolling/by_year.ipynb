# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

import glob

# %%
conn = db.OpsimDatabase('rolling_scale0.8_nslice2_v1.7_10yrs.db')
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

bundleList = []
for year in range(1,11):
    sql = 'night < %f and note not like "DD%%"' % ((365.25*year) )
    metric = metrics.CountMetric('filter')
    slicer = slicers.HealpixSlicer()
    summaryStats = []
    plotDict = {'xlabel': 'Number of Observations', 'title': 'year < %i' % year}
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,
                                                 plotDict=plotDict,
                                                 summaryMetrics=summaryStats))
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night < 365.250000 and note not like "DD%" for columns ['fieldRA', 'filter', 'fieldDec']
# Found 202862 visits
# ...

# %%
conn = db.OpsimDatabase('rolling_scale0.8_nslice2_v1.7_10yrs.db')

bundleList = []
for year in range(1, 11):
    sql = 'night < %f and note not like "DD%%"' % ((365.25*year+365.25/2) )
    metric = metrics.CountMetric('filter')
    slicer = slicers.HealpixSlicer()
    summaryStats = []
    plotDict = {'xlabel': 'Number of Observations', 'title': 'year < %.1f' % (year+0.5)}
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,
                                                 plotDict=plotDict,
                                                 summaryMetrics=summaryStats))
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night < 3835.125000 and note not like "DD%" for columns ['fieldRA', 'filter', 'fieldDec']
# Found 1952969 visits
# ...
