# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
outDir='rolling'
resultsDb = db.ResultsDb(outDir=outDir)

name2file = {
'rolling_2_0.2' : 'rolling_nm_scale0.2_nslice2_v1.7_10yrs.db',
'rolling_2_0.6' : 'rolling_nm_scale0.6_nslice2_v1.7_10yrs.db',
'rolling_2_0.9' : 'rolling_nm_scale0.9_nslice2_v1.7_10yrs.db',
'rolling_3_0.9' : 'rolling_nm_scale0.2_nslice3_v1.7_10yrs.db',
'rolling_3_0.6' : 'rolling_nm_scale0.6_nslice3_v1.7_10yrs.db',
'rolling_3_0.9' : 'rolling_nm_scale0.9_nslice3_v1.7_10yrs.db',
'rolling_2_0.4' : 'rolling_nm_scale0.4_nslice2_v1.7_10yrs.db',
'rolling_2_0.8' : 'rolling_nm_scale0.8_nslice2_v1.7_10yrs.db',
'rolling_2_1.0' : 'rolling_nm_scale1.0_nslice2_v1.7_10yrs.db',
'rolling_3_0.4' : 'rolling_nm_scale0.4_nslice3_v1.7_10yrs.db',
'rolling_3_0.8' : 'rolling_nm_scale0.8_nslice3_v1.7_10yrs.db',
'rolling_3_1.0' : 'rolling_nm_scale1.0_nslice3_v1.7_10yrs.db'
}

# %%
for name in name2file:
    conn = db.OpsimDatabase(name2file[name])
    
    bundleList = []
    sql = 'night > %f and night < %f and note not like "DD%%"' % ((365.25*3.5), (365.25*4.5) )
    metric = metrics.CountMetric('filter')
    slicer = slicers.HealpixSlicer()
    summaryStats = []
    plotDict = {'xlabel': 'Number of Observations', 'title':name, 'colorMin':0, 'colorMax': 280}
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,
                                                 plotDict=plotDict,
                                                 summaryMetrics=summaryStats,
                                                 runName=name))
    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
    bg.runAll()
    bg.plotAll(closefigs=False)
    conn.close()
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1278.375000 and night < 1643.625000 and note not like "DD%" for columns ['fieldRA', 'filter', 'fieldDec']
# Found 204387 visits
# Running:  ['rolling_2_0_2_Count_filter_night_gt_1278_375000_and_night_lt_1643_625000_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1278.375000 and night < 1643.625000 and note not like "DD%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 67.1217  dipole: lon: -145.721, lat: -86.2462, amp: 15.8837
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# ...
