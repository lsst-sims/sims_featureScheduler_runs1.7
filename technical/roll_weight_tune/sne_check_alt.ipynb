# %%
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import sqlite3
import numpy as np
from lsst.sims.maf.metrics.snNSNMetric import SNNSNMetric
import healpy as hp

# %%
files = ['baseline_nexp1_v1.7_10yrs.db',
         'baseline_nexp2_v1.7_10yrs.db',
         'rolling_nm_scale0.75_nslice2_fpw0.6_unc_v1.7_10yrs.db',
         'rolling_nm_scale0.75_nslice3_fpw0.6_unc_v1.7_10yrs.db']

# %%
nside = 4

# %%
# %%time
all_results = []
for filename in files:
    opsimdb = db.OpsimDatabase(filename)
    runName = filename.replace('.db', '')
    slicer = slicers.HealpixSlicer(nside=nside)

    metric = SNNSNMetric(verbose=False)  #, zlim_coeff=0.98)

    bundleList = []

    sql = ''
    #sql = '(note = "%s")' %('DD:COSMOS')
    summaryStats = [metrics.SumMetric(), metrics.MedianMetric()]
    bundleList.append(metricBundles.MetricBundle(metric, slicer, sql, runName=runName, summaryMetrics=summaryStats))
    outDir = 'temp'
    resultsDb = db.ResultsDb(outDir=outDir)
    bundleDict = metricBundles.makeBundlesDictFromList(bundleList)
    bgroup = metricBundles.MetricBundleGroup(bundleDict, opsimdb, outDir=outDir, resultsDb=resultsDb)
    bgroup.runAll()
    bgroup.plotAll(closefigs=False)
    all_results.append(bgroup)
# Out:
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 54522 699 78
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 63609 699 91
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 77589 699 111
# Querying database SummaryAllProps with no constraint for columns ['filter', 'observationId', 'night', 'fieldRA', 'numExposures', 'fieldDec', 'visitTime', 'observationStartMJD', 'visitExposureTime', 'fiveSigmaDepth'].
# Found 2208619 visits
# Running:  ['baseline_nexp1_v1_7_10yrs_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 212.106  dipole: lon: 131.385, lat: -46.2606, amp: 206.078
#   mono, lon, lat, amp
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 0.0518989  dipole: lon: 115.356, lat: 42.5697, amp: 0.203189
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 54522 699 78
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 63609 699 91
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 77589 699 111
# Querying database SummaryAllProps with no constraint for columns ['filter', 'observationId', 'night', 'fieldRA', 'numExposures', 'fieldDec', 'visitTime', 'observationStartMJD', 'visitExposureTime', 'fiveSigmaDepth'].
# Found 2045493 visits
# Running:  ['baseline_nexp2_v1_7_10yrs_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 180.749  dipole: lon: 132.469, lat: -44.6324, amp: 172.672
#   mono, lon, lat, amp
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 0.0602844  dipole: lon: 115.027, lat: 53.9003, amp: 0.229297
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 54522 699 78
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 63609 699 91
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 77589 699 111
# Querying database SummaryAllProps with no constraint for columns ['filter', 'observationId', 'night', 'fieldRA', 'numExposures', 'fieldDec', 'visitTime', 'observationStartMJD', 'visitExposureTime', 'fiveSigmaDepth'].
# Found 1988567 visits
# Running:  ['rolling_nm_scale0_75_nslice2_fpw0_6_unc_v1_7_10yrs_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 198.015  dipole: lon: 114.095, lat: -55.3216, amp: 191.235
#   mono, lon, lat, amp
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 0.010031  dipole: lon: 105.239, lat: 24.2893, amp: 0.173221
#   mono, lon, lat, amp
# Plotting complete.
# Healpix slicer using NSIDE=4, approximate resolution 879.484521 arcminutes
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 54522 699 78
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_-2.0_0.2_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 63609 699 91
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 g 18174 699 26
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 i 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 r 44037 699 63
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 y 68502 699 98
# Loading  /Users/yoachim/git_repos/sims_maf_contrib/data/SNe_data/LC_0.0_0.0_380.0_800.0_ebvofMW_0.0_vstack.hdf5 z 77589 699 111
# Querying database SummaryAllProps with no constraint for columns ['filter', 'observationId', 'night', 'fieldRA', 'numExposures', 'fieldDec', 'visitTime', 'observationStartMJD', 'visitExposureTime', 'fiveSigmaDepth'].
# Found 1988839 visits
# Running:  ['rolling_nm_scale0_75_nslice3_fpw0_6_unc_v1_7_10yrs_SNNSNMetric_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:518: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn('Cannot plot object metric values with this plotter.')
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 203.019  dipole: lon: 115.761, lat: -57.388, amp: 195.639
#   mono, lon, lat, amp
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:127: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:364: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:214: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 0.0293551  dipole: lon: 98.2826, lat: 35.7066, amp: 0.176682
#   mono, lon, lat, amp
# Plotting complete.
# CPU times: user 48min 12s, sys: 3min 34s, total: 51min 46s
# Wall time: 53min 9s

# %%
for bd in all_results:
    print(bd.bundleDict['SNNSNMetric_nSN'].runName)
    print('N SN', bd.bundleDict['SNNSNMetric_nSN'].summaryValues['Sum'])
    print('median z', bd.bundleDict['SNNSNMetric_zlim'].summaryValues['Median'])
    print('----------')
# Out:
# baseline_nexp1_v1.7_10yrs
# N SN 33981.971
# median z 0.25
# ----------
# baseline_nexp2_v1.7_10yrs
# N SN 28722.829999999998
# median z 0.25
# ----------
# rolling_nm_scale0.75_nslice2_fpw0.6_unc_v1.7_10yrs
# N SN 32498.714000000004
# median z 0.25
# ----------
# rolling_nm_scale0.75_nslice3_fpw0.6_unc_v1.7_10yrs
# N SN 33387.186
# median z 0.25
# ----------
