# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.plots as plots
import glob
from scipy.stats import binned_statistic, mode

from pltrollspot import spot_inspect

# %%
dbfiles = glob.glob('*10yrs.db')
dbfiles.sort()

# %%
fig, ax = spot_inspect(dbfiles[0], 0., -20.)
# Out:
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2045493 visits
# Running:  ['baseline_nexp2_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
for filename in dbfiles:
    fig, ax = spot_inspect(filename, 0., -20.)
# Out:
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2045493 visits
# Running:  ['baseline_nexp2_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2041947 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw0_6_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2041138 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw0_6v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2035648 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw0_9_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2036674 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw0_9v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2030203 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_2_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2032104 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_2v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2025537 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_5_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2028462 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_5v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2021189 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_8_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2023865 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw1_8v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2016202 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_1_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2019335 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_1v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2012448 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_4_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2015245 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_4v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2007838 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_7_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2010795 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw2_7v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2004620 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw3_0_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2007027 visits
# Running:  ['rolling_nm_scale0_9_nslice2_fpw3_0v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 1991381 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw0_6_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2042208 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw0_6v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2039960 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw0_9_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2038261 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw0_9v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2033937 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_2_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2035089 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_2v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2028109 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_5_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Found 2030934 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_5v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2022669 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_8_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2027068 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw1_8v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2017865 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_1_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Found 2023617 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_1v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2013406 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_4_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2019415 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_4v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2007954 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_7_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2014954 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw2_7v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2005139 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw3_0_unc_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# Querying database SummaryAllProps with no constraint for columns ['night', 'fieldDec', 'fiveSigmaDepth', 'fieldRA', 'observationStartMJD', 'filter'].
# Found 2010957 visits
# Running:  ['rolling_nm_scale0_9_nslice3_fpw3_0v1_7_10yrs_db_Pass_filter_observationStartMJD_fiveSigmaDepth_night_USER']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# /Users/yoachim/git_repos/sims_featureScheduler_runs1.7/technical/roll_weight_tune/pltrollspot.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

# %%
#fig, ax = spot_inspect(dbfiles[5],200., -20.)
