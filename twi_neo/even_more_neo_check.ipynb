# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.plots as plots

# %%
dbFile = 'twi_neo_pattern1_v1.7_10yrs.db'
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql = 'note like "twi%"'
metric = metrics.CountMetric(col='night')
slicer = slicers.HealpixSlicer()
summaryStats = [metrics.SumMetric()]
plotDict = {}
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))

sql = 'note like "twi%" and night=1'
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))


# The alt/az plots of all the pointings
sql = 'note like "twi%"'
slicer = slicers.HealpixSlicer(useCache=False,latCol='altitude',
                            lonCol='azimuth')
metric = metrics.CountMetric('night', metricName='Nvisits as function of Alt/Az')
plotFuncs = [plots.LambertSkyMap()]

plotDict = {'norm': 'log'}
bundle = metricBundles.MetricBundle(metric, slicer, sql, plotFuncs=plotFuncs)
bundleList.append(bundle)


# The alt/az plots of all the pointings
sql = 'note like "twi%" and moonAlt < -10'
slicer = slicers.HealpixSlicer(useCache=False,latCol='altitude',
                            lonCol='azimuth')
metric = metrics.CountMetric('night', metricName='Nvisits as function of Alt/Az, no moon')
plotFuncs = [plots.LambertSkyMap()]

plotDict = {'norm': 'log'}
bundle = metricBundles.MetricBundle(metric, slicer, sql, plotFuncs=plotFuncs)
bundleList.append(bundle)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint note like "twi%" and moonAlt < -10 for columns ['altitude', 'night', 'azimuth']
# Found 505638 visits
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_no_moon_note_like_twi_and_moonAlt_lt_-10_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint note like "twi%" and night=1 for columns ['night', 'fieldDec', 'fieldRA']
# Found 417 visits
# Running:  ['opsim_Count_night_note_like_twi_and_night1_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint note like "twi%" for columns ['fieldDec', 'altitude', 'fieldRA', 'night', 'azimuth']
# Found 1180054 visits
# Running:  ['opsim_Count_night_note_like_twi_HEAL']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_note_like_twi_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "note like "twi%" and moonAlt < -10" constraint now.
# Plotting complete.
# Plotting figures with "note like "twi%" and night=1" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 6.48843  dipole: lon: 7.42599, lat: -13.3309, amp: 2.59591
#   mono, lon, lat, amp
# Plotting complete.
# Plotting figures with "note like "twi%"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 459.32  dipole: lon: 72.0991, lat: -75.1973, amp: 486.734
#   mono, lon, lat, amp
# Plotting complete.

# %%
bundleList = []
sql = 'note like "twi%"'
metric = metrics.CountMetric(col='night')
slicer = slicers.HealpixSlicer()
summaryStats = [metrics.SumMetric()]



sql = 'note like "twi%" and night=1'
bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, summaryMetrics=summaryStats))


# The alt/az plots of all the pointings
sql = 'note like "twi%"'
slicer = slicers.HealpixSlicer(useCache=False,latCol='altitude',
                            lonCol='azimuth')
metric = metrics.CountMetric('night', metricName='Nvisits as function of Alt/Az')
plotFuncs = [plots.LambertSkyMap()]

plotDict = {'norm': 'log'}
bundle = metricBundles.MetricBundle(metric, slicer, sql, plotFuncs=plotFuncs)
bundleList.append(bundle)


# The alt/az plots of all the pointings
sql = 'note like "twi%" and sunAz < 180'
slicer = slicers.HealpixSlicer(useCache=False,latCol='altitude',
                            lonCol='azimuth')
metric = metrics.CountMetric('night', metricName='Nvisits as function of Alt/Az, small sun Az')
plotFuncs = [plots.LambertSkyMap()]

plotDict = {'norm': 'log'}
bundle = metricBundles.MetricBundle(metric, slicer, sql, plotFuncs=plotFuncs)
bundleList.append(bundle)


# The alt/az plots of all the pointings
sql = 'note like "twi%" and sunAz > 180'
slicer = slicers.HealpixSlicer(useCache=False,latCol='altitude',
                            lonCol='azimuth')
metric = metrics.CountMetric('night', metricName='Nvisits as function of Alt/Az, large sun Az')
plotFuncs = [plots.LambertSkyMap()]

plotDict = {'norm': 'log'}
bundle = metricBundles.MetricBundle(metric, slicer, sql, plotFuncs=plotFuncs)
bundleList.append(bundle)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint note like "twi%" and sunAz < 180 for columns ['altitude', 'night', 'azimuth']
# Found 545686 visits
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_small_sun_Az_note_like_twi_and_sunAz_lt_180_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint note like "twi%" and sunAz > 180 for columns ['altitude', 'night', 'azimuth']
# Found 634368 visits
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_large_sun_Az_note_like_twi_and_sunAz_gt_180_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint note like "twi%" and night=1 for columns ['night', 'fieldDec', 'fieldRA']
# Found 417 visits
# Running:  ['opsim_Count_night_note_like_twi_and_night1_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint note like "twi%" for columns ['altitude', 'night', 'azimuth']
# Found 1180054 visits
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_note_like_twi_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "note like "twi%" and sunAz < 180" constraint now.
# Plotting complete.
# Plotting figures with "note like "twi%" and sunAz > 180" constraint now.
# Plotting complete.
# Plotting figures with "note like "twi%" and night=1" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/healpy/pixelfunc.py:1583: UserWarning: monopole: 6.48843  dipole: lon: 7.42599, lat: -13.3309, amp: 2.59591
#   mono, lon, lat, amp
# Plotting complete.
# Plotting figures with "note like "twi%"" constraint now.
# Plotting complete.
